# %% [markdown]
# # TAT-ONE-TAP Demo
# Memory Management for LLMs

# %%
import sys
sys.path.insert(0, '.')from src.tat_memory import TATMemory
print('✅ TATMemory imported')

# %%
# Create memory instance
memory = TATMemory()
print('✅ Memory instance created')

# %%
# Save a session
memory.save_session({
    'id': 'demo_session',
    'topics': 'TAT-ONE-TAP demo',
    'summary': 'First test of TATMemory'
})
print('✅ Session saved')

# %%
# Restore brain
brain = memory.restore()
print('✅ Brain restored:')
print(brain[:200] + '...')

# %% [markdown]
# ## Next Steps
# - Add your own dialog history
# - Explore modules: TAT-BRAIN, TAT-INDEX, TAT-DIFF, TAT-PRIORITY, TAT-ACHIEVEMENTS
